# %% [markdown]
# <a href="https://colab.research.google.com/github/kanujmalik/DataScience_Projects/blob/master/Simple_NeuralNetwork_.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from tensorflow import keras

# %%
model = keras.Sequential([keras.layers.Dense(units=1, input_shape=[1])])

# %%
model.compile(optimizer='sgd', loss='mean_squared_error')

# %%
import numpy as np
xs = np.array([-1, 0, 1, 2, 3, 4])
y= np.array([-3, -1, 1, 3, 5, 7])

# %%
model.fit(xs, y, epochs=500)
# Out:
# Epoch 1/500
# 1/1 [==============================] - 0s 2ms/step - loss: 16.7052
# Epoch 2/500
# 1/1 [==============================] - 0s 1ms/step - loss: 13.3923
# Epoch 3/500
# 1/1 [==============================] - 0s 2ms/step - loss: 10.7807
# Epoch 4/500
# 1/1 [==============================] - 0s 1ms/step - loss: 8.7210
# Epoch 5/500
# 1/1 [==============================] - 0s 2ms/step - loss: 7.0956
# Epoch 6/500
# 1/1 [==============================] - 0s 5ms/step - loss: 5.8120
# Epoch 7/500
# 1/1 [==============================] - 0s 3ms/step - loss: 4.7974
# Epoch 8/500
# 1/1 [==============================] - 0s 2ms/step - loss: 3.9946
# Epoch 9/500
# 1/1 [==============================] - 0s 3ms/step - loss: 3.3584
# Epoch 10/500
# 1/1 [==============================] - 0s 5ms/step - loss: 2.8535
# Epoch 11/500
# 1/1 [==============================] - 0s 1ms/step - loss: 2.4519
# Epoch 12/500
# 1/1 [==============================] - 0s 1ms/step - loss: 2.1317
# ...

# %%
model.predict([10])
# Out:
# array([[18.981287]], dtype=float32)
